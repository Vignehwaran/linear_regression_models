# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("Salary_dataset.csv")

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
# %matplotlib  inline
from weakref import ref


plt.xlabel("YearofExperice")
plt.ylabel("Salary")
plt.scatter(df.YearsExperience,df.Salary,color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 get_ipython().run_line_magic('matplotlib', ' inline')
#       2 from weakref import ref
# ----> 5 plt.xlabel("YearofExperice")
#       6 plt.ylabel("Salary")
#       7 plt.scatter(df.YearsExperience,df.Salary,color="red")
#
# NameError: name 'plt' is not defined

# %%
#create object the linear regression model 
reg=LinearRegression()
reg.fit(df[['YearsExperience']],df.Salary)
reg.predict([[10]])
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([119347.82718107])

# %% [markdown]
# Behind the scene
#
# linearAlgebra y=mx+b
# m=>slope or Gradient between the x and y axis
# b=>y intetcept

# %%
reg.coef_
# Out:
# array([9449.96232146])

# %%
reg.intercept_
# Out:
# np.float64(24848.203966523193)

# %%
9449.96232146*10+24848.203966523193
# Out:
# 119347.8271811232

# %%
plt.scatter(df['YearsExperience'], df['Salary'], color='red')  # Scatter plot of the data
plt.plot(df['YearsExperience'], reg.predict(df[['YearsExperience']]), color='blue')  # Regression line
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Years of Experience vs Salary')
# Out:
# Text(0.5, 1.0, 'Years of Experience vs Salary')

# %%
reg.predict([[4.5]])
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([67373.03441307])
