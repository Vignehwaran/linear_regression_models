# %%
import pandas as pd
import matplotlib.pyplot as plt
from  sklearn.linear_model  import LinearRegression

# %%
df=pd.read_csv("/workspaces/codespaces-blank/canada_per_capita_income.csv")
df.head()
# Out:
#    year  per_capita_income
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484
# 3  1973        4804.463248
# 4  1974        5576.514583

# %%
# %matplotlib inline

plt.scatter(df.year,df.per_capita_income,color="red")
model=LinearRegression()
#34229.19363 previous year
model.fit(df[["year"]],df.per_capita_income)
model.predict([[2017]])
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(df.year,df.per_capita_income,color="red")
plt.plot(df.year,model.predict(df[["year"]]) ,color="green" )
